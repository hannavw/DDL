# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#Csv to dataframe
df = pd.read_csv('class_data.csv')
df.head()
# Out:
#    id  gender  instagram_followers  linkedin_con  texts_yesterday  \
# 0   1    male                  0.0         642.0             47.0
# 1   2  female                155.0         157.0            150.0
# 2   3  female                169.0         119.0             20.0
# 3   4    male                  NaN         150.0            100.0
# 4   5    male                 25.0         120.0            420.0
#
#    phones_owned  apps_phone os_phone like_social       like_tech
# 0           7.0       101.0  Android   Undecided       Undecided
# 1           8.0        44.0      iOS       Agree           Agree
# 2           5.0        65.0      iOS       Agree           Agree
# 3           5.0        67.0  Android       Agree  Strongly agree
# 4           2.0        70.0  Android   Undecided           Agree

# %%
#Get the realistic data
df_subset = df[df['instagram_followers']<800]

# %%
#Plot the data about Instagram followers
sns.distplot(df_subset['instagram_followers'], kde=False, bins=9)
plt.title('Amount of Instagram followers per student')
plt.xlabel('Amount of followers')
plt.ylabel('Amount of students')
plt.show()
# Out:
# C:\Users\Gebruiker\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#Plot the data about phones owned
df['phones_owned'].name = 'Amount of phones' #Labeling the variable for plotting
sns.distplot(amount_of_phones) 
plt.title('Phones owned')
plt.ylabel('% of Students')
plt.show()
# Out:
# C:\Users\Gebruiker\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#Plot the data about LinkedIn connections
sns.boxplot(df['linkedin_con'])
plt.title('Amount of Linked-In connections')
plt.xlabel('Linkedin Connections')
plt.show()

# %%
#Plot the data about texts yesterday
sns.violinplot(df['texts_yesterday'])
sns.swarmplot(df['texts_yesterday'], color='yellow')
plt.title('Amount of text on a sunday')
plt.ylabel('Students')
plt.xlabel('Amount of texts')
plt.show()

# %%
mean_size = df['apps_phone'].mean()
median_size = df['apps_phone'].median()

print(f'The median filesize is: {median_size} MB')
print(f'The mean filesize is: {mean_size} MB')

#note: need to copy code
sns.distplot(file_size, bins=9) 
plt.title('apps_phone')
plt.axvline(median_size, 0, 100, color='green', label='median') #This adds a vertical line at x-position median_size, from y = 0 to y = 100 
plt.axvline(mean_size, 0, 100, color='blue', label='mean') 
plt.legend()
plt.show()
# Out:
# The median filesize is: 70.0 MB
# The mean filesize is: 206.6086956521739 MB
# C:\Users\Gebruiker\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#df_ = df[df['price'] > 0] #Subsetting the dataframe to include only paid apps
sns.violinplot(df['apps_phone'])
sns.swarmplot(df['apps_phone'], color='yellow') #default color doesn't stand out
plt.title('Amount of apps on phone')
plt.ylabel('Students')
plt.xlabel('Amount of apps')
plt.show()
